# %% [markdown]
# # Task 1:

# %%
#Data analysis and wrangling
import numpy as np
import pandas as pd

#Data Visualization
import graphviz
import seaborn as sns
from sklearn import tree
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.feature_selection import RFE
from sklearn.feature_selection import chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

#Model selection and evaluation
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### 1. Preprocess your Titanic training data

# %%
# Load in the train and test datasets

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

combine_df = [train_df, test_df]

# Store our passenger ID for easy access
PassengerId = test_df['PassengerId']

train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
test_df = test_df.drop(['Ticket', 'Cabin'], axis=1)
combine_df = [train_df, test_df]

for dataset in combine_df:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# fill missing values with median column values
train_df.fillna(train_df.median(), inplace=True)
test_df.fillna(test_df.median(), inplace=True)

# Fill embarked with mode
freq_port = train_df.Embarked.dropna().mode()[0]
for dataset in combine_df:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)
    
# complete Fare using mode
test_df['Fare'].fillna(test_df['Fare'].dropna().median(), inplace=True)    

# update combine_df
combine_df = [train_df, test_df]

# Convert the Fare feature to ordinal values
for dataset in combine_df:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
#Convert categorical variables into numeric
for dataset in combine_df:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
#Drop Name,PassengerId
train_df = train_df.drop(['Name','PassengerId'], axis=1)
test_df = test_df.drop(['Name','PassengerId'], axis=1)
# Out:
# <ipython-input-4-a8af8bf426fb>:19: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_df.fillna(train_df.median(), inplace=True)
# <ipython-input-4-a8af8bf426fb>:20: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   test_df.fillna(test_df.median(), inplace=True)

# %%
#Correlations
k  = 8
corrmat = train_df.corr()
cols = corrmat.nlargest(k, 'Survived')['Survived'].index
cm = np.corrcoef(train_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, \
                 square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#Modeling 
X_train = train_df.drop(["Survived"], axis=1)
Y_train = train_df["Survived"]
X_test  = test_df.drop(["SibSp"], axis=1)
X_train.shape, Y_train.shape, X_test.shape
# Out:
# ((891, 7), (891,), (418, 6))

# %%
# For each X, calculate VIF and save in dataframe

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif["features"] = X_train.columns
vif.round(1)
# Out:
#    VIF Factor  features
# 0         3.8    Pclass
# 1         1.7       Sex
# 2         5.1       Age
# 3         1.8     SibSp
# 4         1.7     Parch
# 5         4.1      Fare
# 6         1.4  Embarked

# %%
#Feature selection using RFE
model = LogisticRegression()
rfe = RFE(model)
fit = rfe.fit(X_train, Y_train)
print("Num Features: ",fit.n_features_)
print("Selected Features: ",fit.support_)
print("Feature Ranking: ",fit.ranking_)
print(X_train.head())
# Out:
# Num Features:  3
# Selected Features:  [ True  True False False False False  True]
# Feature Ranking:  [1 1 5 2 4 3 1]
#    Pclass  Sex   Age  SibSp  Parch  Fare  Embarked
# 0       3    0  22.0      1      0     0         0
# 1       1    1  38.0      1      0     3         1
# 2       3    1  26.0      0      0     1         0
# 3       1    1  35.0      1      0     3         0
# 4       3    0  35.0      0      0     1         0

# %%
#Feature selection using SelectKBest
Kbestscore = SelectKBest(score_func=chi2, k=4)
fit = Kbestscore.fit(X_train, Y_train)
# summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X_train)
# summarize selected features
print(features[0:5,:])
print (X_train.head())
# Out:
# [ 30.874 170.348  21.649   2.582  10.097  64.722  11.353]
# [[ 3.  0. 22.  0.]
#  [ 1.  1. 38.  3.]
#  [ 3.  1. 26.  1.]
#  [ 1.  1. 35.  3.]
#  [ 3.  0. 35.  1.]]
#    Pclass  Sex   Age  SibSp  Parch  Fare  Embarked
# 0       3    0  22.0      1      0     0         0
# 1       1    1  38.0      1      0     3         1
# 2       3    1  26.0      0      0     1         0
# 3       1    1  35.0      1      0     3         0
# 4       3    0  35.0      0      0     1         0

# %%
#Drop variables after feature selection:

X_train_df = train_df.drop(["Survived","SibSp","Parch","Embarked"], axis=1)
Y_train_df = train_df["Survived"]
X_test_df  = test_df.drop(["SibSp","Parch","Embarked"], axis=1)
X_train_df.shape, Y_train_df.shape, X_test_df.shape
# Out:
# ((891, 4), (891,), (418, 4))

# %% [markdown]
# ## Plotting the Decision Tree:

# %% [markdown]
# ### 2. Learn and fine-tune a decision tree model with the Titanic training data, plot your decision tree (5 points )

# %%
dt = DecisionTreeClassifier(criterion='gini',random_state = 42)
dt.fit(X_train, Y_train)

DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
                       max_depth=None, max_features=None, max_leaf_nodes=None,
                       min_impurity_decrease=0.0,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, 
                       random_state=42, splitter='best')

plt.figure(figsize=(30,20))  
feature_names = list(X_train.columns)
class_names = ['died','survived']
tree.plot_tree(dt, fontsize=10, filled=True,feature_names=feature_names, class_names=class_names)
# Out:
# [Text(0.4451499607252038, 0.9761904761904762, 'Sex <= 0.5\ngini = 0.473\nsamples = 891\nvalue = [549, 342]\nclass = died'),
#  Text(0.12811411981997284, 0.9285714285714286, 'Age <= 6.5\ngini = 0.306\nsamples = 577\nvalue = [468, 109]\nclass = died'),
#  Text(0.02309782608695652, 0.8809523809523809, 'SibSp <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]\nclass = survived'),
#  Text(0.017663043478260868, 0.8333333333333334, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = survived'),
#  Text(0.028532608695652172, 0.8333333333333334, 'Age <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = died'),
#  Text(0.02309782608695652, 0.7857142857142857, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = died'),
#  Text(0.033967391304347824, 0.7857142857142857, 'Age <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.028532608695652172, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.03940217391304348, 0.7380952380952381, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.23313041355298914, 0.8809523809523809, 'Pclass <= 1.5\ngini = 0.28\nsamples = 553\nvalue = [460, 93]\nclass = died'),
#  Text(0.10122282608695653, 0.8333333333333334, 'Age <= 53.0\ngini = 0.46\nsamples = 120\nvalue = [77, 43]\nclass = died'),
#  Text(0.05570652173913043, 0.7857142857142857, 'Fare <= 1.0\ngini = 0.483\nsamples = 98\nvalue = [58, 40]\nclass = died'),
#  Text(0.050271739130434784, 0.7380952380952381, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = died'),
#  Text(0.06114130434782609, 0.7380952380952381, 'Fare <= 2.5\ngini = 0.491\nsamples = 92\nvalue = [52, 40]\nclass = died'),
#  Text(0.03260869565217391, 0.6904761904761905, 'Age <= 47.5\ngini = 0.489\nsamples = 33\nvalue = [14, 19]\nclass = survived'),
#  Text(0.02717391304347826, 0.6428571428571429, 'Age <= 45.25\ngini = 0.498\nsamples = 30\nvalue = [14, 16]\nclass = survived'),
#  Text(0.021739130434782608, 0.5952380952380952, 'Age <= 31.0\ngini = 0.49\nsamples = 28\nvalue = [12, 16]\nclass = survived'),
#  Text(0.010869565217391304, 0.5476190476190477, 'Age <= 27.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = died'),
#  Text(0.005434782608695652, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.016304347826086956, 0.5, 'Age <= 28.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = died'),
#  Text(0.010869565217391304, 0.4523809523809524, 'Embarked <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]\nclass = died'),
#  Text(0.005434782608695652, 0.40476190476190477, 'gini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = died'),
#  Text(0.016304347826086956, 0.40476190476190477, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.021739130434782608, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.03260869565217391, 0.5476190476190477, 'Age <= 36.5\ngini = 0.375\nsamples = 12\nvalue = [3, 9]\nclass = survived'),
#  Text(0.02717391304347826, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = survived'),
#  Text(0.03804347826086957, 0.5, 'Age <= 38.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = died'),
#  Text(0.03260869565217391, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.043478260869565216, 0.4523809523809524, 'Embarked <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = survived'),
#  Text(0.03804347826086957, 0.40476190476190477, 'Age <= 43.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.03260869565217391, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.043478260869565216, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.04891304347826087, 0.40476190476190477, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.03260869565217391, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.03804347826086957, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = survived'),
#  Text(0.08967391304347826, 0.6904761904761905, 'Age <= 17.5\ngini = 0.458\nsamples = 59\nvalue = [38, 21]\nclass = died'),
#  Text(0.08423913043478261, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.09510869565217392, 0.6428571428571429, 'SibSp <= 0.5\ngini = 0.444\nsamples = 57\nvalue = [38, 19]\nclass = died'),
#  Text(0.07608695652173914, 0.5952380952380952, 'Age <= 37.0\ngini = 0.337\nsamples = 28\nvalue = [22, 6]\nclass = died'),
#  Text(0.07065217391304347, 0.5476190476190477, 'Age <= 33.0\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = died'),
#  Text(0.059782608695652176, 0.5, 'Age <= 22.5\ngini = 0.346\nsamples = 18\nvalue = [14, 4]\nclass = died'),
#  Text(0.05434782608695652, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.06521739130434782, 0.4523809523809524, 'Age <= 23.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]\nclass = died'),
#  Text(0.059782608695652176, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.07065217391304347, 0.40476190476190477, 'Age <= 25.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = died'),
#  Text(0.06521739130434782, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.07608695652173914, 0.35714285714285715, 'Age <= 27.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = died'),
#  Text(0.06521739130434782, 0.30952380952380953, 'Parch <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.059782608695652176, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.07065217391304347, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.08695652173913043, 0.30952380952380953, 'Embarked <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = died'),
#  Text(0.08152173913043478, 0.2619047619047619, 'Age <= 29.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = died'),
#  Text(0.07608695652173914, 0.21428571428571427, 'gini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = died'),
#  Text(0.08695652173913043, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.09239130434782608, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.08152173913043478, 0.5, 'Age <= 35.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.07608695652173914, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.08695652173913043, 0.4523809523809524, 'Parch <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.08152173913043478, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.09239130434782608, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.08152173913043478, 0.5476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = died'),
#  Text(0.11413043478260869, 0.5952380952380952, 'Age <= 22.0\ngini = 0.495\nsamples = 29\nvalue = [16, 13]\nclass = died'),
#  Text(0.10869565217391304, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.11956521739130435, 0.5476190476190477, 'Age <= 27.5\ngini = 0.5\nsamples = 26\nvalue = [13, 13]\nclass = died'),
#  Text(0.11413043478260869, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = survived'),
#  Text(0.125, 0.5, 'Age <= 30.0\ngini = 0.491\nsamples = 23\nvalue = [13, 10]\nclass = died'),
#  Text(0.11956521739130435, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.13043478260869565, 0.4523809523809524, 'Parch <= 1.5\ngini = 0.499\nsamples = 21\nvalue = [11, 10]\nclass = died'),
#  Text(0.125, 0.40476190476190477, 'Embarked <= 1.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]\nclass = died'),
#  Text(0.11956521739130435, 0.35714285714285715, 'SibSp <= 1.5\ngini = 0.499\nsamples = 19\nvalue = [10, 9]\nclass = died'),
#  Text(0.11413043478260869, 0.30952380952380953, 'Age <= 49.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = died'),
#  Text(0.10869565217391304, 0.2619047619047619, 'Age <= 47.0\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = survived'),
#  Text(0.09782608695652174, 0.21428571428571427, 'Age <= 43.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = died'),
#  Text(0.09239130434782608, 0.16666666666666666, 'Parch <= 0.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = died'),
#  Text(0.08695652173913043, 0.11904761904761904, 'Age <= 37.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = died'),
#  Text(0.07608695652173914, 0.07142857142857142, 'Age <= 33.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.07065217391304347, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.08152173913043478, 0.023809523809523808, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.09782608695652174, 0.07142857142857142, 'Age <= 40.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.09239130434782608, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.10326086956521739, 0.023809523809523808, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.09782608695652174, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.10326086956521739, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.11956521739130435, 0.21428571428571427, 'Parch <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = survived'),
#  Text(0.11413043478260869, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = survived'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.11956521739130435, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.125, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.13043478260869565, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.1358695652173913, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.14673913043478262, 0.7857142857142857, 'Age <= 75.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]\nclass = died'),
#  Text(0.14130434782608695, 0.7380952380952381, 'Embarked <= 0.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]\nclass = died'),
#  Text(0.1358695652173913, 0.6904761904761905, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = died'),
#  Text(0.14673913043478262, 0.6904761904761905, 'SibSp <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = died'),
#  Text(0.14130434782608695, 0.6428571428571429, 'Age <= 57.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = died'),
#  Text(0.1358695652173913, 0.5952380952380952, 'Fare <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.13043478260869565, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.14130434782608695, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.14673913043478262, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = died'),
#  Text(0.15217391304347827, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.15217391304347827, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.36503800101902173, 0.8333333333333334, 'Age <= 13.0\ngini = 0.204\nsamples = 433\nvalue = [383, 50]\nclass = died'),
#  Text(0.26248301630434784, 0.7857142857142857, 'SibSp <= 2.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = died'),
#  Text(0.25704823369565216, 0.7380952380952381, 'Embarked <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = survived'),
#  Text(0.25161345108695654, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = survived'),
#  Text(0.26248301630434784, 0.6904761904761905, 'Fare <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.25704823369565216, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.26791779891304346, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.26791779891304346, 0.7380952380952381, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = died'),
#  Text(0.4675929857336957, 0.7857142857142857, 'Age <= 32.25\ngini = 0.195\nsamples = 421\nvalue = [375, 46]\nclass = died'),
#  Text(0.40529466711956524, 0.7380952380952381, 'Age <= 30.75\ngini = 0.221\nsamples = 316\nvalue = [276, 40]\nclass = died'),
#  Text(0.3391219429347826, 0.6904761904761905, 'Embarked <= 0.5\ngini = 0.193\nsamples = 295\nvalue = [263, 32]\nclass = died'),
#  Text(0.27878736413043476, 0.6428571428571429, 'Parch <= 0.5\ngini = 0.161\nsamples = 226\nvalue = [206, 20]\nclass = died'),
#  Text(0.27335258152173914, 0.5952380952380952, 'Fare <= 2.5\ngini = 0.173\nsamples = 209\nvalue = [189, 20]\nclass = died'),
#  Text(0.24235733695652173, 0.5476190476190477, 'Fare <= 1.5\ngini = 0.156\nsamples = 200\nvalue = [183, 17]\nclass = died'),
#  Text(0.23692255434782608, 0.5, 'SibSp <= 0.5\ngini = 0.171\nsamples = 180\nvalue = [163, 17]\nclass = died'),
#  Text(0.18036684782608695, 0.4523809523809524, 'Age <= 19.5\ngini = 0.162\nsamples = 169\nvalue = [154, 15]\nclass = died'),
#  Text(0.14673913043478262, 0.40476190476190477, 'Fare <= 0.5\ngini = 0.225\nsamples = 31\nvalue = [27, 4]\nclass = died'),
#  Text(0.14130434782608695, 0.35714285714285715, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = died'),
#  Text(0.15217391304347827, 0.35714285714285715, 'Age <= 18.5\ngini = 0.32\nsamples = 20\nvalue = [16, 4]\nclass = died'),
#  Text(0.14130434782608695, 0.30952380952380953, 'Pclass <= 2.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = died'),
#  Text(0.1358695652173913, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.14673913043478262, 0.2619047619047619, 'Age <= 17.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = died'),
#  Text(0.14130434782608695, 0.21428571428571427, 'Age <= 16.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = died'),
#  Text(0.1358695652173913, 0.16666666666666666, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.14673913043478262, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.15217391304347827, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.16304347826086957, 0.30952380952380953, 'Pclass <= 2.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = died'),
#  Text(0.15760869565217392, 0.2619047619047619, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.16847826086956522, 0.2619047619047619, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.2139945652173913, 0.40476190476190477, 'Age <= 23.5\ngini = 0.147\nsamples = 138\nvalue = [127, 11]\nclass = died'),
#  Text(0.19021739130434784, 0.35714285714285715, 'Fare <= 0.5\ngini = 0.05\nsamples = 39\nvalue = [38, 1]\nclass = died'),
#  Text(0.18478260869565216, 0.30952380952380953, 'Age <= 21.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = died'),
#  Text(0.1793478260869565, 0.2619047619047619, 'Age <= 20.75\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = died'),
#  Text(0.17391304347826086, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.18478260869565216, 0.21428571428571427, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = died'),
#  Text(0.19021739130434784, 0.2619047619047619, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = died'),
#  Text(0.1956521739130435, 0.30952380952380953, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = died'),
#  Text(0.23777173913043478, 0.35714285714285715, 'Age <= 27.5\ngini = 0.182\nsamples = 99\nvalue = [89, 10]\nclass = died'),
#  Text(0.21195652173913043, 0.30952380952380953, 'Age <= 26.5\ngini = 0.271\nsamples = 31\nvalue = [26, 5]\nclass = died'),
#  Text(0.20108695652173914, 0.2619047619047619, 'Fare <= 0.5\ngini = 0.147\nsamples = 25\nvalue = [23, 2]\nclass = died'),
#  Text(0.1956521739130435, 0.21428571428571427, 'Age <= 25.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = died'),
#  Text(0.19021739130434784, 0.16666666666666666, 'Age <= 24.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = died'),
#  Text(0.18478260869565216, 0.11904761904761904, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = died'),
#  Text(0.1956521739130435, 0.11904761904761904, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = died'),
#  Text(0.20108695652173914, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.20652173913043478, 0.21428571428571427, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = died'),
#  Text(0.22282608695652173, 0.2619047619047619, 'Pclass <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = died'),
#  Text(0.21739130434782608, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.22826086956521738, 0.21428571428571427, 'Fare <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = survived'),
#  Text(0.22282608695652173, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.23369565217391305, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.26358695652173914, 0.30952380952380953, 'Fare <= 0.5\ngini = 0.136\nsamples = 68\nvalue = [63, 5]\nclass = died'),
#  Text(0.24456521739130435, 0.2619047619047619, 'Pclass <= 2.5\ngini = 0.056\nsamples = 35\nvalue = [34, 1]\nclass = died'),
#  Text(0.2391304347826087, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = died'),
#  Text(0.25, 0.21428571428571427, 'Age <= 28.5\ngini = 0.067\nsamples = 29\nvalue = [28, 1]\nclass = died'),
#  Text(0.24456521739130435, 0.16666666666666666, 'gini = 0.077\nsamples = 25\nvalue = [24, 1]\nclass = died'),
#  Text(0.2554347826086957, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.2826086956521739, 0.2619047619047619, 'Age <= 28.5\ngini = 0.213\nsamples = 33\nvalue = [29, 4]\nclass = died'),
#  Text(0.2717391304347826, 0.21428571428571427, 'Pclass <= 2.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]\nclass = died'),
#  Text(0.266304347826087, 0.16666666666666666, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.27717391304347827, 0.16666666666666666, 'gini = 0.111\nsamples = 17\nvalue = [16, 1]\nclass = died'),
#  Text(0.29347826086956524, 0.21428571428571427, 'Pclass <= 2.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = died'),
#  Text(0.28804347826086957, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = died'),
#  Text(0.29891304347826086, 0.16666666666666666, 'Age <= 30.25\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = died'),
#  Text(0.29347826086956524, 0.11904761904761904, 'Age <= 29.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = died'),
#  Text(0.28804347826086957, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.29891304347826086, 0.07142857142857142, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.30434782608695654, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.29347826086956524, 0.4523809523809524, 'Age <= 25.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = died'),
#  Text(0.28804347826086957, 0.40476190476190477, 'Age <= 19.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = died'),
#  Text(0.2826086956521739, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.29347826086956524, 0.35714285714285715, 'Age <= 20.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = died'),
#  Text(0.28804347826086957, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.29891304347826086, 0.30952380952380953, 'Age <= 23.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.29347826086956524, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.30434782608695654, 0.2619047619047619, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.29891304347826086, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.24779211956521738, 0.5, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = died'),
#  Text(0.30434782608695654, 0.5476190476190477, 'Age <= 25.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = died'),
#  Text(0.29891304347826086, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.30978260869565216, 0.5, 'Age <= 27.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = survived'),
#  Text(0.30434782608695654, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.31521739130434784, 0.4523809523809524, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = died'),
#  Text(0.28422214673913043, 0.5952380952380952, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = died'),
#  Text(0.39945652173913043, 0.6428571428571429, 'Parch <= 0.5\ngini = 0.287\nsamples = 69\nvalue = [57, 12]\nclass = died'),
#  Text(0.3804347826086957, 0.5952380952380952, 'SibSp <= 1.5\ngini = 0.245\nsamples = 63\nvalue = [54, 9]\nclass = died'),
#  Text(0.358695652173913, 0.5476190476190477, 'Age <= 22.5\ngini = 0.228\nsamples = 61\nvalue = [53, 8]\nclass = died'),
#  Text(0.33152173913043476, 0.5, 'Embarked <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = died'),
#  Text(0.32608695652173914, 0.4523809523809524, 'Age <= 21.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = died'),
#  Text(0.32065217391304346, 0.40476190476190477, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.33152173913043476, 0.40476190476190477, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.33695652173913043, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.3858695652173913, 0.5, 'Age <= 28.75\ngini = 0.194\nsamples = 55\nvalue = [49, 6]\nclass = died'),
#  Text(0.358695652173913, 0.4523809523809524, 'Pclass <= 2.5\ngini = 0.15\nsamples = 49\nvalue = [45, 4]\nclass = died'),
#  Text(0.3423913043478261, 0.40476190476190477, 'Fare <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.33695652173913043, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.34782608695652173, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.375, 0.40476190476190477, 'Age <= 26.5\ngini = 0.122\nsamples = 46\nvalue = [43, 3]\nclass = died'),
#  Text(0.358695652173913, 0.35714285714285715, 'Age <= 25.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = died'),
#  Text(0.3532608695652174, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.3641304347826087, 0.30952380952380953, 'SibSp <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.358695652173913, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.3695652173913043, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.391304347826087, 0.35714285714285715, 'Fare <= 0.5\ngini = 0.093\nsamples = 41\nvalue = [39, 2]\nclass = died'),
#  Text(0.3858695652173913, 0.30952380952380953, 'SibSp <= 0.5\ngini = 0.117\nsamples = 32\nvalue = [30, 2]\nclass = died'),
#  Text(0.3804347826086957, 0.2619047619047619, 'Age <= 28.25\ngini = 0.121\nsamples = 31\nvalue = [29, 2]\nclass = died'),
#  Text(0.375, 0.21428571428571427, 'Embarked <= 1.5\ngini = 0.124\nsamples = 30\nvalue = [28, 2]\nclass = died'),
#  Text(0.3695652173913043, 0.16666666666666666, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = died'),
#  Text(0.3804347826086957, 0.16666666666666666, 'gini = 0.111\nsamples = 17\nvalue = [16, 1]\nclass = died'),
#  Text(0.3858695652173913, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.391304347826087, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.3967391304347826, 0.30952380952380953, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = died'),
#  Text(0.41304347826086957, 0.4523809523809524, 'Age <= 29.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = died'),
#  Text(0.4076086956521739, 0.40476190476190477, 'Fare <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.40217391304347827, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.41304347826086957, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.41847826086956524, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.40217391304347827, 0.5476190476190477, 'Embarked <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.3967391304347826, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.4076086956521739, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.41847826086956524, 0.5952380952380952, 'Age <= 18.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = died'),
#  Text(0.41304347826086957, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.42391304347826086, 0.5476190476190477, 'Parch <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = survived'),
#  Text(0.41847826086956524, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = survived'),
#  Text(0.42934782608695654, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.47146739130434784, 0.6904761904761905, 'Embarked <= 0.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = died'),
#  Text(0.46603260869565216, 0.6428571428571429, 'Parch <= 0.5\ngini = 0.494\nsamples = 18\nvalue = [10, 8]\nclass = died'),
#  Text(0.46059782608695654, 0.5952380952380952, 'SibSp <= 1.5\ngini = 0.498\nsamples = 17\nvalue = [9, 8]\nclass = died'),
#  Text(0.45516304347826086, 0.5476190476190477, 'Fare <= 2.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]\nclass = died'),
#  Text(0.44972826086956524, 0.5, 'Fare <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]\nclass = died'),
#  Text(0.43478260869565216, 0.4523809523809524, 'Age <= 31.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.42934782608695654, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.44021739130434784, 0.40476190476190477, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.46467391304347827, 0.4523809523809524, 'Age <= 31.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = died'),
#  Text(0.45108695652173914, 0.40476190476190477, 'Pclass <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.44565217391304346, 0.35714285714285715, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.45652173913043476, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.4782608695652174, 0.40476190476190477, 'SibSp <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = died'),
#  Text(0.4673913043478261, 0.35714285714285715, 'Pclass <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = died'),
#  Text(0.46195652173913043, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.47282608695652173, 0.30952380952380953, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = died'),
#  Text(0.4891304347826087, 0.35714285714285715, 'Pclass <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.483695652173913, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.4945652173913043, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.46059782608695654, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.46603260869565216, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.47146739130434784, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.47690217391304346, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.529891304347826, 0.7380952380952381, 'Fare <= 0.5\ngini = 0.108\nsamples = 105\nvalue = [99, 6]\nclass = died'),
#  Text(0.5244565217391305, 0.6904761904761905, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]\nclass = died'),
#  Text(0.5353260869565217, 0.6904761904761905, 'Fare <= 1.5\ngini = 0.151\nsamples = 73\nvalue = [67, 6]\nclass = died'),
#  Text(0.529891304347826, 0.6428571428571429, 'Age <= 38.5\ngini = 0.223\nsamples = 47\nvalue = [41, 6]\nclass = died'),
#  Text(0.5163043478260869, 0.5952380952380952, 'Pclass <= 2.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]\nclass = died'),
#  Text(0.5108695652173914, 0.5476190476190477, 'Age <= 34.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = died'),
#  Text(0.5054347826086957, 0.5, 'Age <= 33.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.5, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.5108695652173914, 0.4523809523809524, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.5163043478260869, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died'),
#  Text(0.5217391304347826, 0.5476190476190477, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = died'),
#  Text(0.5434782608695652, 0.5952380952380952, 'Age <= 46.0\ngini = 0.285\nsamples = 29\nvalue = [24, 5]\nclass = died'),
#  Text(0.532608695652174, 0.5476190476190477, 'Age <= 44.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = died'),
#  Text(0.5271739130434783, 0.5, 'SibSp <= 1.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]\nclass = died'),
#  Text(0.5217391304347826, 0.4523809523809524, 'Parch <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]\nclass = died'),
#  Text(0.5163043478260869, 0.40476190476190477, 'Age <= 43.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = died'),
#  Text(0.5108695652173914, 0.35714285714285715, 'Age <= 42.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = died'),
#  Text(0.5054347826086957, 0.30952380952380953, 'Pclass <= 2.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = died'),
#  Text(0.4945652173913043, 0.2619047619047619, 'Age <= 40.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.4891304347826087, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.5, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.5163043478260869, 0.2619047619047619, 'Age <= 40.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.5108695652173914, 0.21428571428571427, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.5217391304347826, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.5163043478260869, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.5217391304347826, 0.35714285714285715, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.5271739130434783, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.532608695652174, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.5380434782608695, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.5543478260869565, 0.5476190476190477, 'Age <= 60.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = died'),
#  Text(0.5489130434782609, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = died'),
#  Text(0.5597826086956522, 0.5, 'Age <= 64.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.5543478260869565, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.5652173913043478, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.5407608695652174, 0.6428571428571429, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]\nclass = died'),
#  Text(0.7621858016304348, 0.9285714285714286, 'Pclass <= 2.5\ngini = 0.383\nsamples = 314\nvalue = [81, 233]\nclass = survived'),
#  Text(0.6304347826086957, 0.8809523809523809, 'Age <= 2.5\ngini = 0.1\nsamples = 170\nvalue = [9, 161]\nclass = survived'),
#  Text(0.6141304347826086, 0.8333333333333334, 'Pclass <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.6086956521739131, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6195652173913043, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.6467391304347826, 0.8333333333333334, 'Fare <= 2.5\ngini = 0.091\nsamples = 168\nvalue = [8, 160]\nclass = survived'),
#  Text(0.6304347826086957, 0.7857142857142857, 'Age <= 56.0\ngini = 0.171\nsamples = 74\nvalue = [7, 67]\nclass = survived'),
#  Text(0.6141304347826086, 0.7380952380952381, 'Age <= 37.0\ngini = 0.153\nsamples = 72\nvalue = [6, 66]\nclass = survived'),
#  Text(0.5978260869565217, 0.6904761904761905, 'Age <= 27.5\ngini = 0.105\nsamples = 54\nvalue = [3, 51]\nclass = survived'),
#  Text(0.592391304347826, 0.6428571428571429, 'Age <= 25.5\ngini = 0.185\nsamples = 29\nvalue = [3, 26]\nclass = survived'),
#  Text(0.5815217391304348, 0.5952380952380952, 'Fare <= 1.5\ngini = 0.077\nsamples = 25\nvalue = [1, 24]\nclass = survived'),
#  Text(0.5760869565217391, 0.5476190476190477, 'Age <= 23.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = survived'),
#  Text(0.5706521739130435, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = survived'),
#  Text(0.5815217391304348, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.5869565217391305, 0.5476190476190477, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = survived'),
#  Text(0.6032608695652174, 0.5952380952380952, 'Fare <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = died'),
#  Text(0.5978260869565217, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.6086956521739131, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.6032608695652174, 0.6428571428571429, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]\nclass = survived'),
#  Text(0.6304347826086957, 0.6904761904761905, 'Age <= 39.0\ngini = 0.278\nsamples = 18\nvalue = [3, 15]\nclass = survived'),
#  Text(0.625, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6358695652173914, 0.6428571428571429, 'Embarked <= 0.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]\nclass = survived'),
#  Text(0.625, 0.5952380952380952, 'SibSp <= 0.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = survived'),
#  Text(0.6195652173913043, 0.5476190476190477, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = survived'),
#  Text(0.6304347826086957, 0.5476190476190477, 'Age <= 44.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = survived'),
#  Text(0.625, 0.5, 'Age <= 43.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.6195652173913043, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.6304347826086957, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6358695652173914, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.6467391304347826, 0.5952380952380952, 'Age <= 47.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.6413043478260869, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.6521739130434783, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6467391304347826, 0.7380952380952381, 'Fare <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.6413043478260869, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6521739130434783, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.6630434782608695, 0.7857142857142857, 'Parch <= 1.5\ngini = 0.021\nsamples = 94\nvalue = [1, 93]\nclass = survived'),
#  Text(0.657608695652174, 0.7380952380952381, 'gini = 0.0\nsamples = 79\nvalue = [0, 79]\nclass = survived'),
#  Text(0.6684782608695652, 0.7380952380952381, 'Age <= 24.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]\nclass = survived'),
#  Text(0.6630434782608695, 0.6904761904761905, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = survived'),
#  Text(0.6739130434782609, 0.6904761904761905, 'Age <= 28.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = survived'),
#  Text(0.6684782608695652, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6793478260869565, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = survived'),
#  Text(0.893936820652174, 0.8809523809523809, 'Embarked <= 0.5\ngini = 0.5\nsamples = 144\nvalue = [72, 72]\nclass = died'),
#  Text(0.8517323369565217, 0.8333333333333334, 'SibSp <= 1.5\ngini = 0.469\nsamples = 88\nvalue = [55, 33]\nclass = died'),
#  Text(0.8067255434782609, 0.7857142857142857, 'Age <= 27.5\ngini = 0.495\nsamples = 67\nvalue = [37, 30]\nclass = died'),
#  Text(0.7574728260869565, 0.7380952380952381, 'Parch <= 0.5\ngini = 0.486\nsamples = 36\nvalue = [15, 21]\nclass = survived'),
#  Text(0.7160326086956522, 0.6904761904761905, 'Fare <= 0.5\ngini = 0.5\nsamples = 26\nvalue = [13, 13]\nclass = died'),
#  Text(0.6902173913043478, 0.6428571428571429, 'Age <= 18.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]\nclass = survived'),
#  Text(0.6793478260869565, 0.5952380952380952, 'Age <= 16.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.6739130434782609, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.6847826086956522, 0.5476190476190477, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.7010869565217391, 0.5952380952380952, 'Age <= 24.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]\nclass = survived'),
#  Text(0.6956521739130435, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = survived'),
#  Text(0.7065217391304348, 0.5476190476190477, 'Age <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.7010869565217391, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.7119565217391305, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.7418478260869565, 0.6428571428571429, 'Age <= 11.5\ngini = 0.444\nsamples = 15\nvalue = [10, 5]\nclass = died'),
#  Text(0.7364130434782609, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.7472826086956522, 0.5952380952380952, 'Age <= 25.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = died'),
#  Text(0.7336956521739131, 0.5476190476190477, 'Age <= 19.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = died'),
#  Text(0.7228260869565217, 0.5, 'SibSp <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.717391304347826, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.7282608695652174, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.7445652173913043, 0.5, 'Fare <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = died'),
#  Text(0.7391304347826086, 0.4523809523809524, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = died'),
#  Text(0.75, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.7608695652173914, 0.5476190476190477, 'Fare <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.7554347826086957, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.7663043478260869, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.7989130434782609, 0.6904761904761905, 'Age <= 14.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = survived'),
#  Text(0.7934782608695652, 0.6428571428571429, 'Age <= 7.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = survived'),
#  Text(0.7880434782608695, 0.5952380952380952, 'Fare <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = survived'),
#  Text(0.782608695652174, 0.5476190476190477, 'Age <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.7771739130434783, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.7880434782608695, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.7934782608695652, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.7989130434782609, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.8043478260869565, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = survived'),
#  Text(0.8559782608695652, 0.7380952380952381, 'Age <= 38.5\ngini = 0.412\nsamples = 31\nvalue = [22, 9]\nclass = died'),
#  Text(0.8369565217391305, 0.6904761904761905, 'Fare <= 1.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]\nclass = died'),
#  Text(0.8152173913043478, 0.6428571428571429, 'Age <= 29.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]\nclass = died'),
#  Text(0.8097826086956522, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = died'),
#  Text(0.8206521739130435, 0.5952380952380952, 'Fare <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = died'),
#  Text(0.8152173913043478, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.8260869565217391, 0.5476190476190477, 'Age <= 34.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = died'),
#  Text(0.8206521739130435, 0.5, 'Age <= 30.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.8152173913043478, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.8260869565217391, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.8315217391304348, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.8586956521739131, 0.6428571428571429, 'Age <= 33.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = survived'),
#  Text(0.8532608695652174, 0.5952380952380952, 'Parch <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = died'),
#  Text(0.8478260869565217, 0.5476190476190477, 'Age <= 29.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = survived'),
#  Text(0.842391304347826, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.8532608695652174, 0.5, 'Parch <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.8478260869565217, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.8586956521739131, 0.4523809523809524, 'Age <= 30.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.8532608695652174, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.8641304347826086, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.8586956521739131, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.8641304347826086, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = survived'),
#  Text(0.875, 0.6904761904761905, 'Age <= 55.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = died'),
#  Text(0.8695652173913043, 0.6428571428571429, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = died'),
#  Text(0.8804347826086957, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.8967391304347826, 0.7857142857142857, 'Age <= 30.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]\nclass = died'),
#  Text(0.8913043478260869, 0.7380952380952381, 'Fare <= 1.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]\nclass = died'),
#  Text(0.8858695652173914, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.8967391304347826, 0.6904761904761905, 'Age <= 5.5\ngini = 0.1\nsamples = 19\nvalue = [18, 1]\nclass = died'),
#  Text(0.8913043478260869, 0.6428571428571429, 'Age <= 4.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.8858695652173914, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = died'),
#  Text(0.8967391304347826, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9021739130434783, 0.6428571428571429, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = died'),
#  Text(0.9021739130434783, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.936141304347826, 0.8333333333333334, 'Age <= 29.75\ngini = 0.423\nsamples = 56\nvalue = [17, 39]\nclass = survived'),
#  Text(0.9307065217391305, 0.7857142857142857, 'Age <= 7.0\ngini = 0.375\nsamples = 52\nvalue = [13, 39]\nclass = survived'),
#  Text(0.9252717391304348, 0.7380952380952381, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = survived'),
#  Text(0.936141304347826, 0.7380952380952381, 'Age <= 11.0\ngini = 0.4\nsamples = 47\nvalue = [13, 34]\nclass = survived'),
#  Text(0.9307065217391305, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.9415760869565217, 0.6904761904761905, 'Fare <= 0.5\ngini = 0.386\nsamples = 46\nvalue = [12, 34]\nclass = survived'),
#  Text(0.9130434782608695, 0.6428571428571429, 'Parch <= 1.0\ngini = 0.302\nsamples = 27\nvalue = [5, 22]\nclass = survived'),
#  Text(0.907608695652174, 0.5952380952380952, 'Age <= 21.5\ngini = 0.26\nsamples = 26\nvalue = [4, 22]\nclass = survived'),
#  Text(0.8967391304347826, 0.5476190476190477, 'Age <= 17.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = survived'),
#  Text(0.8913043478260869, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = survived'),
#  Text(0.9021739130434783, 0.5, 'Age <= 18.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = died'),
#  Text(0.8967391304347826, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.907608695652174, 0.4523809523809524, 'Age <= 20.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.9021739130434783, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9130434782608695, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.9184782608695652, 0.5476190476190477, 'Embarked <= 1.5\ngini = 0.188\nsamples = 19\nvalue = [2, 17]\nclass = survived'),
#  Text(0.9130434782608695, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = survived'),
#  Text(0.9239130434782609, 0.5, 'Age <= 25.0\ngini = 0.208\nsamples = 17\nvalue = [2, 15]\nclass = survived'),
#  Text(0.9184782608695652, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9293478260869565, 0.4523809523809524, 'gini = 0.219\nsamples = 16\nvalue = [2, 14]\nclass = survived'),
#  Text(0.9184782608695652, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.970108695652174, 0.6428571428571429, 'Embarked <= 1.5\ngini = 0.465\nsamples = 19\nvalue = [7, 12]\nclass = survived'),
#  Text(0.9510869565217391, 0.5952380952380952, 'Parch <= 1.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = died'),
#  Text(0.9402173913043478, 0.5476190476190477, 'Age <= 14.25\ngini = 0.469\nsamples = 8\nvalue = [5, 3]\nclass = died'),
#  Text(0.9347826086956522, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9456521739130435, 0.5, 'SibSp <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = died'),
#  Text(0.9402173913043478, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.9510869565217391, 0.4523809523809524, 'Parch <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = died'),
#  Text(0.9456521739130435, 0.40476190476190477, 'Age <= 21.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = died'),
#  Text(0.9402173913043478, 0.35714285714285715, 'Age <= 14.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.9347826086956522, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.9456521739130435, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9510869565217391, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = died'),
#  Text(0.9565217391304348, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9619565217391305, 0.5476190476190477, 'Age <= 26.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = survived'),
#  Text(0.9565217391304348, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.967391304347826, 0.5, 'Age <= 28.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = survived'),
#  Text(0.9619565217391305, 0.4523809523809524, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.9728260869565217, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9891304347826086, 0.5952380952380952, 'Fare <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = survived'),
#  Text(0.9836956521739131, 0.5476190476190477, 'Age <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = died'),
#  Text(0.9782608695652174, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = survived'),
#  Text(0.9891304347826086, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = died'),
#  Text(0.9945652173913043, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = survived'),
#  Text(0.9415760869565217, 0.7857142857142857, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = died')]

# %%
### Using Max Depth for defining depth of the Tree

decision_tree = DecisionTreeClassifier(criterion='gini',random_state = 42, max_depth=4)
clf = decision_tree.fit(X_train, Y_train)

feature_names = list(X_train.columns)

# %%
tree_data = tree.export_graphviz(decision_tree, out_file=None, 
                                feature_names=feature_names,  
                                class_names=['0','1'],
                                filled=True)

# Draw graph
graph = graphviz.Source(tree_data, format="png") 
graph.save("DT.png")
graph

# %% [markdown]
# ## 5-Fold Cross Validation:

# %% [markdown]
# ### 3. Apply the five-fold cross validation of your fine-tuned decision tree learning model to the Titanic training data to extract average classification accuracy (5 points)

# %%
#Model - Decision tree using GIni index - accuracy and AUC; 

# Create Decision Tree classifer object
decision_tree = DecisionTreeClassifier(max_depth=4)
clf = decision_tree.fit(X_train, Y_train)
acc = cross_val_score(clf, X_train, Y_train, cv=5)
scores = cross_val_score(clf, X_train, Y_train, cv=5, scoring='roc_auc')

print("5K CV Decision tree classification accuracy:", acc)
print("5K CV Decision tree average classification accuracy: ", acc.mean())
print("=== Mean AUC Score ===")
print("Training Mean AUC Score - Decision tree: ", scores.mean())
# Out:
# 5K CV Decision tree classification accuracy: [0.804 0.815 0.809 0.787 0.86 ]
# 5K CV Decision tree average classification accuracy:  0.8148264390182665
# === Mean AUC Score ===
# Training Mean AUC Score - Decision tree:  0.8426856939606535

# %% [markdown]
# ### 4. Apply the five-fold cross validation of your fine-tuned random forest learning model to the Titanic training data to extract average classification accuracy (5 points)

# %%
#Model - random forest- accuracy and AUC; 

random_forest = RandomForestClassifier(n_estimators=400,random_state = 22)
rff = random_forest.fit(X_train, Y_train)
acc = cross_val_score(rff, X_train, Y_train, cv=5)
scores = cross_val_score(rff, X_train, Y_train, cv=5, scoring='roc_auc')

print("5K CV Random Forest classification accuracy:", acc)
print("5K CV Random Forest average classification accuracy: ", acc.mean())
print("=== Mean AUC Score ===")
print("Training Mean AUC Score - Random Forest: ", scores.mean())
# Out:
# 5K CV Random Forest classification accuracy: [0.793 0.787 0.831 0.792 0.843]
# 5K CV Random Forest average classification accuracy:  0.8092210156299041
# === Mean AUC Score ===
# Training Mean AUC Score - Random Forest:  0.845765939149348

# %% [markdown]
# ### 5. Which algorithm is better, Decision Tree or Random Forest? What are your observations and conclusions from the algorithm comparison and analysis? (5 points)

# %%
#after variable selection F1

X = train_df.drop(columns=['Survived','SibSp','Parch','Embarked']).values
Y = train_df['Survived'].values
XX_train_df, XX_test, YY_train_df, YY_test = train_test_split(X, Y, test_size = 0.2, random_state = 22)

# Building Decision Tree
dt = DecisionTreeClassifier(criterion = 'gini', random_state = 22)
dt.fit(XX_train_df, YY_train_df)
dt_pred_train_df = dt.predict(XX_train_df)

# Evaluation on train_dfing set
dt_pred_train_df = dt.predict(XX_train_df)
print('DT train_dfing Set Evaluation F1-Score=>',f1_score(YY_train_df,dt_pred_train_df))

# Evaluating on Test set
dt_pred_test = dt.predict(XX_test)
print('DT Validation Set Evaluation F1-Score=>',f1_score(YY_test,dt_pred_test))

# Building  Random Forest Classifier
rfc = RandomForestClassifier(criterion = 'entropy', random_state = 22)
rfc.fit(XX_train_df, YY_train_df)

# Evaluating on train_dfing set
rfc_pred_train_df = rfc.predict(XX_train_df)
print('RF train_dfing Set Evaluation F1-Score=>',f1_score(YY_train_df,rfc_pred_train_df))

# Evaluating on Test set
rfc_pred_test = rfc.predict(XX_test)
print('RF Validation Set Evaluation F1-Score=>',f1_score(YY_test,rfc_pred_test))
# Out:
# DT train_dfing Set Evaluation F1-Score=> 0.8988326848249028
# DT Validation Set Evaluation F1-Score=> 0.7299270072992701
# RF train_dfing Set Evaluation F1-Score=> 0.9011406844106464
# RF Validation Set Evaluation F1-Score=> 0.7375886524822696

# %% [markdown]
# ***Obervations:***

# %% [markdown]
# - `Random forest is a bagging method by combining week classifers into a stronger prediction model and also de-correlated variables, thus reduce variance and overffiting. It generally has better performance than decision tree.`

# %% [markdown]
# ## Task 6:

# %% [markdown]
# **Construct a support vector machine that computes the kernel function. Use four values of +1 and -1 for both inputs and outputs: (20 points)**

# %% [markdown]
#         [−1, −1] (negative)
#
#         [−1, +1] (positive)
#
#         [+1, −1] (positive)
#
#         [+1, +1] (negative).
#
# - Map the input [x1, x2] into a space consisting of x1 and x1x2. Draw the four input points in this space, and the maximal margin separator. What is the margin? 【 To be consistent with our lecture notes, margin is defined as the distance from the middle way/hyperplane to either support vectors. 】

# %%
## Plotting data

x = np.array([[-1,-1],
              [-1,1],
              [1,-1],
              [1,1]])

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)

ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes

ax.spines['right'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')

# Show ticks in the left and lower axes only

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.scatter(x[:,0],x[:,1],c=['r','b','b','r'])
plt.text(-1.2,-1.05,'_', fontsize=20)
plt.text(1.05,-1.1,'+', fontsize=20)
plt.text(1.05,1.3,'_', fontsize=20)
plt.text(-1.05,1.1,'+', fontsize=20)
plt.text(2,0.15,'$x_1$', fontsize=15)
plt.text(0.1,1.9,'$x_2$', fontsize=15)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('Scatter plot of data to be classified')
# Out:
# Text(0.5, 1.0, 'Scatter plot of data to be classified')

# %% [markdown]
# ### Transforming input [x1, x2] into a space consisting of x1 and x1x2.

# %%
x1x2 = np.prod(x,axis=1)
x_new = np.array([x[:,0], x1x2]).T
x_new
# Out:
# array([[-1,  1],
#        [-1, -1],
#        [ 1, -1],
#        [ 1,  1]])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('black')
ax.spines['top'].set_color('black')
ax.spines['left'].set_color('black')
ax.spines['bottom'].set_color('black')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
a = np.arange(-2,2.2,0.1)

plt.scatter(x_new[:,0],x_new[:,1],c=['r','b','b','r'])
plt.plot(a,np.zeros_like(a),'b--')
plt.text(-1.25,-1.15,'+', fontsize=20)
plt.text(1.05,-1.1,'+', fontsize=20)
plt.text(1.05,1.3,'_', fontsize=20)
plt.text(-1.15,1.3,'_', fontsize=20)
plt.text(1.5,-0.5,r'Maximum margin separator $x_1x_2 = 0$')
plt.text(2,0.15,'$x_1$', fontsize=15)
plt.text(0.1,1.9,'$x_1x_2$', fontsize=15)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('Scatter plot of transformed data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of transformed data')

# %% [markdown]
#     Note: In the above figure, the horizontal axis represents x1 and the vertical axis represents x1x2.

# %% [markdown]
#     From the figure above, we can see that after transforming the feature vectors from the space of (x1,x2) to (x1,x1x2), all the negative class points are above the x1 axis and all the positive class points are below the x1 axis. Thus, the data is now linearly seprable.
#
#     Notice how the x1x2 = 0 hyperplane (it's a line in our case) separates the two classes with a maximum margin. This is shown by the blue dotted horizontal axis in the figure above. The points are now linearly separable in this new space  (x1,x1x2) by the maximum margin separator hyperplane x1x2 = 0  or by the lines x1 = 0 and x2 = 0 in the original space (x1,x2).

# %% [markdown]
# ***Computing the margin :***
#
# - `Thus, x1x2 = -1 for the positive examples and x1x2 = + 1 for the negative examples. The line x1x2 = 0, with a margin of 1, serves as the maximum margin separator. In the original space, the separator corresponds to the axes at x1 = 0 and x2 = 0. This could be considered the limit of a separator with two hyperbolic branches.`
#
#
# - `The margin can be easly computed by inspection because we know the support vectors and the maximum margin separator. From the above figure, we can see that the margin is 1 because the distance between the support vectors and the separating hyperplane is 1.`
